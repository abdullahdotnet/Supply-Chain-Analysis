# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df  = pd.read_csv('data.csv')
df.head()
# Out:
#   payment_type  profit_per_order  sales_per_customer  category_id  \
# 0        DEBIT         34.448338            92.49099          9.0
# 1     TRANSFER         91.193540           181.99008         48.0
# 2        DEBIT          8.313806            89.96643         46.0
# 3     TRANSFER        -89.463196            99.15065         17.0
# 4        DEBIT         44.722590           170.97824         48.0
#
#           category_name customer_city customer_country  customer_id  \
# 0      Cardio Equipment        Caguas      Puerto Rico   12097.6830
# 1          Water Sports   Albuquerque          EE. UU.    5108.1045
# 2  Indoor/Outdoor Games      Amarillo      Puerto Rico    4293.4478
# 3                Cleats        Caguas      Puerto Rico     546.5306
# 4          Water Sports       Peabody          EE. UU.    1546.3980
#
#   customer_segment customer_state  ...     order_region  \
# 0         Consumer             PR  ...   Western Europe
# 1         Consumer             CA  ...    South America
# 2         Consumer             PR  ...   Western Europe
# 3         Consumer             PR  ...  Central America
# 4         Consumer             CA  ...  Central America
#
#                   order_state order_status  product_card_id  \
# 0                      Vienna     COMPLETE            191.0
# 1                Buenos Aires      PENDING           1073.0
# 2  Nord-Pas-de-Calais-Picardy     COMPLETE           1014.0
# 3                   Santa Ana   PROCESSING            365.0
# 4                    Illinois     COMPLETE           1073.0
#
#    product_category_id                       product_name product_price  \
# 0                  9.0  Nike Men's Free 5.0+ Running Shoe         99.99
# 1                 48.0        Pelican Sunstream 100 Kayak        199.99
# 2                 46.0   O'Brien Men's Neoprene Life Vest         49.98
# 3                 17.0   Perfect Fitness Perfect Rip Deck         59.99
# 4                 48.0        Pelican Sunstream 100 Kayak        199.99
#
#                shipping_date   shipping_mode label
# 0  2015-08-13 00:00:00+01:00  Standard Class    -1
# 1  2017-04-09 00:00:00+01:00  Standard Class    -1
# 2  2015-03-18 00:00:00+00:00    Second Class     1
# 3  2017-03-18 00:00:00+00:00    Second Class     0
# 4  2015-03-30 00:00:00+01:00  Standard Class     1
#
# [5 rows x 41 columns]

# %%
df.shape
# Out:
# (15549, 41)

# %%
df.isnull().sum()
# Out:
# payment_type                0
# profit_per_order            0
# sales_per_customer          0
# category_id                 0
# category_name               0
# customer_city               0
# customer_country            0
# customer_id                 0
# customer_segment            0
# customer_state              0
# customer_zipcode            0
# department_id               0
# department_name             0
# latitude                    0
# longitude                   0
# market                      0
# order_city                  0
# order_country               0
# order_customer_id           0
# order_date                  0
# order_id                    0
# order_item_cardprod_id      0
# order_item_discount         0
# order_item_discount_rate    0
# order_item_id               0
# order_item_product_price    0
# order_item_profit_ratio     0
# order_item_quantity         0
# sales                       0
# order_item_total_amount     0
# order_profit_per_order      0
# order_region                0
# order_state                 0
# order_status                0
# product_card_id             0
# product_category_id         0
# product_name                0
# product_price               0
# shipping_date               0
# shipping_mode               0
# label                       0
# dtype: int64

# %%
df.describe()
# Out:
#        profit_per_order  sales_per_customer   category_id   customer_id  \
# count      15549.000000        15549.000000  15549.000000  15549.000000
# mean          22.604542          179.888256     31.461342   6583.279789
# std           99.265198          113.727323     15.303616   4114.273782
# min        -3442.500000            8.351162      2.000000      1.000000
# 25%            7.562795          104.397330     18.000000   3119.983200
# 50%           31.693370          165.944170     29.000000   6429.229000
# 75%           63.872166          242.440930     45.000000   9642.381000
# max          911.800000         1939.990000     76.000000  20757.000000
#
#        customer_zipcode  department_id      latitude     longitude  \
# count      15549.000000   15549.000000  15549.000000  15549.000000
# mean       35458.234968       5.413462     29.677619    -84.512318
# std        37343.702033       1.581550      9.877876     20.681015
# min          603.000000       2.000000    -33.937553   -158.025990
# 25%          725.000000       4.000000     18.263327    -98.088170
# 50%        19145.775000       5.000000     33.435677    -76.580800
# 75%        77502.820000       7.000000     39.277313    -66.370575
# max        99205.000000      12.000000     48.781933    115.263080
#
#        order_customer_id      order_id  ...  order_item_product_price  \
# count       15549.000000  15549.000000  ...              15549.000000
# mean         6586.810354  35718.970019  ...                137.005272
# std          4101.324290  21071.742668  ...                134.545269
# min             1.000000      1.000000  ...                  9.990000
# 25%          3177.568800  16530.752000  ...                 50.000000
# 50%          6308.530000  35391.336000  ...                 59.990000
# 75%          9703.070000  55236.910000  ...                199.990000
# max         20757.000000  77204.000000  ...               1999.990000
#
#        order_item_profit_ratio  order_item_quantity         sales  \
# count             15549.000000         15549.000000  15549.000000
# mean                  0.120391             2.165202    200.562289
# std                   0.474088             1.468627    125.984986
# min                  -2.750000             1.000000      9.990000
# 25%                   0.080000             1.000000    119.980000
# 50%                   0.270000             1.000000    199.920000
# 75%                   0.360000             3.000000    299.950000
# max                   0.500000             5.000000   1999.990000
#
#        order_item_total_amount  order_profit_per_order  product_card_id  \
# count             15549.000000            15549.000000     15549.000000
# mean                179.780850               22.273342       685.213286
# std                 110.999735              117.503163       330.778230
# min                   7.490000            -3442.500000        19.000000
# 25%                 105.570910                7.443977       403.000000
# 50%                 165.990000               32.440100       627.000000
# 75%                 242.436400               64.303566      1004.000000
# max                1939.990000              911.800000      1363.000000
#
#        product_category_id  product_price         label
# count         15549.000000   15549.000000  15549.000000
# mean             31.387606     136.629368      0.349283
# std              15.256620     133.366285      0.826623
# min               2.000000       9.990000     -1.000000
# 25%              18.000000      50.000000      0.000000
# 50%              29.000000      59.990000      1.000000
# 75%              45.000000     199.990000      1.000000
# max              76.000000    1999.990000      1.000000
#
# [8 rows x 24 columns]

# %%
payment_count = df['payment_type'].value_counts()

# %%
plt.bar(payment_count.index, payment_count.values)
# Out:
# <BarContainer object of 4 artists>

# %%
df['category_name'].value_counts()
# Out:
# category_name
# Cleats                  2212
# Men's Footwear          1931
# Women's Apparel         1906
# Indoor/Outdoor Games    1657
# Fishing                 1426
# Water Sports            1391
# Camping & Hiking        1127
# Shop By Sport           1056
# Cardio Equipment        1049
# Electronics              219
# Accessories              123
# Golf Balls               120
# Golf Gloves              101
# Girls' Apparel            76
# Crafts                    63
# Video Games               63
# Children's Clothing       59
# Trade-In                  58
# Cameras                   57
# Music                     55
# Women's Clothing          52
# Golf Shoes                52
# Baseball & Softball       51
# Pet Supplies              46
# Hockey                    44
# Hunting & Shooting        42
# Toys                      38
# Lacrosse                  37
# Boxing & MMA              33
# Garden                    33
# DVDs                      32
# Soccer                    29
# Tennis & Racquet          29
# Books                     28
# Fitness Accessories       27
# Baby                      27
# Consumer Electronics      23
# Health and Beauty         22
# CDs                       21
# Computers                 21
# As Seen on  TV!           19
# Men's Clothing            19
# Golf Apparel              16
# Sporting Goods            16
# Men's Golf Clubs          12
# Basketball                10
# Kids' Golf Clubs           9
# Strength Training          6
# Women's Golf Clubs         6
# Name: count, dtype: int64

# %%
df['market'].value_counts()
# Out:
# market
# Europe          4578
# LATAM           4414
# Pacific Asia    3518
# USCA            2125
# Africa           914
# Name: count, dtype: int64

# %%
df.drop_duplicates(subset = ['customer_id'],inplace=True)

# %%
df.shape
# Out:
# (15519, 41)

# %%
city_wise_customer = df.groupby('customer_city')['customer_id'].count().reset_index().sort_values(by='customer_id',ascending=False)
city_wise_customer.rename(columns={'customer_city':'City','customer_id':'No. of Customers'},inplace=True)
city_wise_customer.reset_index(drop=True)
# Out:
#             City  No. of Customers
# 0         Caguas              5952
# 1       Brooklyn               300
# 2        Chicago               277
# 3    Los Angeles               259
# 4          Bronx               147
# ..           ...               ...
# 550       Folsom                 1
# 551      Everett                 1
# 552        Irwin                 1
# 553       Upland                 1
# 554     Alhambra                 1
#
# [555 rows x 2 columns]

# %%
df['customer_country'].unique()
# Out:
# array(['Puerto Rico', 'EE. UU.'], dtype=object)

# %%
df['customer_state'].unique()
# Out:
# array(['PR', 'CA', 'KY', 'NJ', 'AZ', 'PA', 'NY', 'OH', 'CO', 'MT', 'WI',
#        'IL', 'DC', 'CT', 'WV', 'UT', 'FL', 'TX', 'MI', 'NM', 'NV', 'WA',
#        'NC', 'GA', 'MD', 'SC', 'TN', 'IN', 'MO', 'MN', 'OR', 'VA', 'MA',
#        'HI', 'RI', 'DE', 'ID', '91732', 'LA', 'ND', 'KS', 'IA', 'OK',
#        'AL'], dtype=object)

# %%
drop = df[df['customer_state'] == '91732'].index

# %%
df.drop(drop)
# Out:
#       payment_type  profit_per_order  sales_per_customer  category_id  \
# 0            DEBIT         34.448338           92.490990          9.0
# 1         TRANSFER         91.193540          181.990080         48.0
# 2            DEBIT          8.313806           89.966430         46.0
# 3         TRANSFER        -89.463196           99.150650         17.0
# 4            DEBIT         44.722590          170.978240         48.0
# ...            ...               ...                 ...          ...
# 15544        DEBIT        108.042500          359.980000         45.0
# 15545        DEBIT         22.480274          169.990000         46.0
# 15546      PAYMENT         15.861091           47.497177         35.0
# 15547     TRANSFER        -23.254063           49.973537         17.0
# 15548     TRANSFER        177.790680          387.973020          9.0
#
#               category_name customer_city customer_country  customer_id  \
# 0          Cardio Equipment        Caguas      Puerto Rico   12097.6830
# 1              Water Sports   Albuquerque          EE. UU.    5108.1045
# 2      Indoor/Outdoor Games      Amarillo      Puerto Rico    4293.4478
# 3                    Cleats        Caguas      Puerto Rico     546.5306
# 4              Water Sports       Peabody          EE. UU.    1546.3980
# ...                     ...           ...              ...          ...
# 15544               Fishing        Caguas      Puerto Rico    8333.1170
# 15545  Indoor/Outdoor Games        Caguas      Puerto Rico    3182.7766
# 15546           Electronics       Del Rio          EE. UU.    9697.5720
# 15547                Cleats        Caguas      Puerto Rico    1953.6525
# 15548      Cardio Equipment        Caguas      Puerto Rico    6012.8926
#
#       customer_segment customer_state  ...     order_region  \
# 0             Consumer             PR  ...   Western Europe
# 1             Consumer             CA  ...    South America
# 2             Consumer             PR  ...   Western Europe
# 3             Consumer             PR  ...  Central America
# 4             Consumer             CA  ...  Central America
# ...                ...            ...  ...              ...
# 15544         Consumer             PR  ...  Central America
# 15545         Consumer             PR  ...    South America
# 15546         Consumer             TX  ...   Western Europe
# 15547         Consumer             PR  ...   Southeast Asia
# 15548         Consumer             PR  ...    South America
#
#                       order_state     order_status  product_card_id  \
# 0                          Vienna         COMPLETE         191.0000
# 1                    Buenos Aires          PENDING        1073.0000
# 2      Nord-Pas-de-Calais-Picardy         COMPLETE        1014.0000
# 3                       Santa Ana       PROCESSING         365.0000
# 4                        Illinois         COMPLETE        1073.0000
# ...                           ...              ...              ...
# 15544                     Managua         COMPLETE        1004.0000
# 15545                     Yucatan         COMPLETE        1014.0000
# 15546      North Rhine-Westphalia  PENDING_PAYMENT         823.7916
# 15547                   West Java          PENDING         365.0000
# 15548                    Tarapaca       PROCESSING         191.0000
#
#        product_category_id                                   product_name  \
# 0                      9.0              Nike Men's Free 5.0+ Running Shoe
# 1                     48.0                    Pelican Sunstream 100 Kayak
# 2                     46.0               O'Brien Men's Neoprene Life Vest
# 3                     17.0               Perfect Fitness Perfect Rip Deck
# 4                     48.0                    Pelican Sunstream 100 Kayak
# ...                    ...                                            ...
# 15544                 45.0      Field & Stream Sportsman 16 Gun Fire Safe
# 15545                 46.0               O'Brien Men's Neoprene Life Vest
# 15546                 35.0  Bridgestone e6 Straight Distance NFL Carolina
# 15547                 17.0               Perfect Fitness Perfect Rip Deck
# 15548                  9.0              Nike Men's Free 5.0+ Running Shoe
#
#       product_price              shipping_date   shipping_mode label
# 0             99.99  2015-08-13 00:00:00+01:00  Standard Class    -1
# 1            199.99  2017-04-09 00:00:00+01:00  Standard Class    -1
# 2             49.98  2015-03-18 00:00:00+00:00    Second Class     1
# 3             59.99  2017-03-18 00:00:00+00:00    Second Class     0
# 4            199.99  2015-03-30 00:00:00+01:00  Standard Class     1
# ...             ...                        ...             ...   ...
# 15544        399.98  2017-04-03 00:00:00+01:00  Standard Class     1
# 15545         49.98  2017-06-05 00:00:00+01:00  Standard Class    -1
# 15546         30.00  2015-05-04 00:00:00+01:00  Standard Class     0
# 15547         59.99  2016-04-07 00:00:00+01:00  Standard Class     1
# 15548         99.99  2017-09-15 00:00:00+01:00    Second Class     1
#
# [15518 rows x 41 columns]

# %%
df['customer_segment'].value_counts()
# Out:
# customer_segment
# Consumer       8319
# Corporate      4594
# Home Office    2606
# Name: count, dtype: int64

# %%
df['sales']
# Out:
# 0         99.990000
# 1        199.990000
# 2         99.960000
# 3        119.980000
# 4        199.990000
#             ...
# 15544    399.980000
# 15545    199.920000
# 15546     59.971092
# 15547     59.990000
# 15548    327.186340
# Name: sales, Length: 15519, dtype: float64

# %%
salessegment = df.groupby('customer_segment')['sales'].sum().reset_index().sort_values(by='sales')
salessegment.rename(columns={'customer_segment': 'Segment','sales':"Total Sales"},inplace=True)

# %%
salessegment
# Out:
#        Segment   Total Sales
# 2  Home Office  5.275029e+05
# 1    Corporate  9.271175e+05
# 0     Consumer  1.658210e+06

# %%
len(df['category_name'].unique())
# Out:
# 49

# %%
len(df['product_name'].unique())
# Out:
# 113

# %%
marketssegment = df.groupby('customer_segment')['sales'].sum().reset_index().sort_values(by='sales')

# %%
df.groupby('customer_segment')['product_name']

# %%
df[['customer_segment','sales','order_profit_per_order']]
# Out:
#       customer_segment       sales  order_profit_per_order
# 0             Consumer   99.990000               32.083145
# 1             Consumer  199.990000               91.235870
# 2             Consumer   99.960000                6.965549
# 3             Consumer  119.980000              -95.401400
# 4             Consumer  199.990000               44.569000
# ...                ...         ...                     ...
# 15544         Consumer  399.980000              102.063774
# 15545         Consumer  199.920000               25.072104
# 15546         Consumer   59.971092               12.163874
# 15547         Consumer   59.990000              -17.863270
# 15548         Consumer  327.186340              181.285060
#
# [15519 rows x 3 columns]

# %%
df.groupby('customer_segment')['order_item_profit_ratio'].mean().reset_index().sort_values(by='order_item_profit_ratio')
# Out:
#   customer_segment  order_item_profit_ratio
# 2      Home Office                 0.105427
# 0         Consumer                 0.120766
# 1        Corporate                 0.130006

# %%
categorysegment = df.groupby(['customer_segment','category_name'])['order_id'].count().reset_index()
categorysegment
# Out:
#     customer_segment        category_name  order_id
# 0           Consumer          Accessories        60
# 1           Consumer      As Seen on  TV!        14
# 2           Consumer                Baby         19
# 3           Consumer  Baseball & Softball        27
# 4           Consumer           Basketball         6
# ..               ...                  ...       ...
# 139      Home Office          Video Games        10
# 140      Home Office         Water Sports       219
# 141      Home Office      Women's Apparel       318
# 142      Home Office     Women's Clothing        14
# 143      Home Office   Women's Golf Clubs         2
#
# [144 rows x 3 columns]

# %%
categorysegment = categorysegment.rename(columns={'order_id': 'Count'})
df_sorted = categorysegment.sort_values('Count', ascending= False)
df_sorted
# Out:
#     customer_segment         category_name  Count
# 12          Consumer                Cleats   1221
# 46          Consumer       Women's Apparel   1027
# 33          Consumer        Men's Footwear    974
# 29          Consumer  Indoor/Outdoor Games    895
# 18          Consumer               Fishing    748
# ..               ...                   ...    ...
# 99       Home Office       As Seen on  TV!      2
# 48          Consumer    Women's Golf Clubs      1
# 104      Home Office          Boxing & MMA      1
# 83         Corporate      Men's Golf Clubs      1
# 102      Home Office            Basketball      1
#
# [144 rows x 3 columns]

# %%
top_5 = df_sorted.groupby('customer_segment').head(5)
top_5
# Out:
#     customer_segment         category_name  Count
# 12          Consumer                Cleats   1221
# 46          Consumer       Women's Apparel   1027
# 33          Consumer        Men's Footwear    974
# 29          Consumer  Indoor/Outdoor Games    895
# 18          Consumer               Fishing    748
# 61         Corporate                Cleats    631
# 82         Corporate        Men's Footwear    610
# 95         Corporate       Women's Apparel    558
# 78         Corporate  Indoor/Outdoor Games    482
# 94         Corporate          Water Sports    436
# 110      Home Office                Cleats    359
# 130      Home Office        Men's Footwear    341
# 141      Home Office       Women's Apparel    318
# 127      Home Office  Indoor/Outdoor Games    276
# 116      Home Office               Fishing    246

# %%
df['order_profit_per_order'].min()
# Out:
# np.float64(-3442.5)

# %%
df['order_profit_per_order'].max()
# Out:
# np.float64(910.84595)

# %%
indextodrop = df[df['order_profit_per_order'] < -1000 ].index
newdf = df.drop(indextodrop)
newdf['order_profit_per_order'].min()
# Out:
# np.float64(-905.37024)

# %%
df.groupby('category_name')['sales'].sum().reset_index().sort_values(by='sales',ascending=False).head(10)
# Out:
#            category_name          sales
# 18               Fishing  569623.580000
# 12                Cleats  397579.794404
# 9       Camping & Hiking  338523.835750
# 10      Cardio Equipment  309026.509476
# 46       Women's Apparel  290673.216714
# 45          Water Sports  278005.822750
# 33        Men's Footwear  251114.020672
# 29  Indoor/Outdoor Games  245787.168565
# 37         Shop By Sport  127437.135745
# 13             Computers   27452.581353

# %%
newdf = df.drop_duplicates(subset=['category_name','product_name'])

# %%
newdf.groupby('category_name')['product_name'].count()
# Out:
# category_name
# Accessories             23
# As Seen on  TV!         13
# Baby                    15
# Baseball & Softball     14
# Basketball               6
# Books                    3
# Boxing & MMA            10
# CDs                      2
# Cameras                  9
# Camping & Hiking         6
# Cardio Equipment        11
# Children's Clothing      4
# Cleats                   3
# Computers                4
# Consumer Electronics     2
# Crafts                  22
# DVDs                     2
# Electronics             28
# Fishing                  2
# Fitness Accessories     10
# Garden                   3
# Girls' Apparel          10
# Golf Apparel             4
# Golf Balls              16
# Golf Gloves             20
# Golf Shoes              15
# Health and Beauty        4
# Hockey                  10
# Hunting & Shooting      13
# Indoor/Outdoor Games     6
# Kids' Golf Clubs         9
# Lacrosse                17
# Men's Clothing           5
# Men's Footwear          14
# Men's Golf Clubs         8
# Music                   19
# Pet Supplies            12
# Shop By Sport           12
# Soccer                  17
# Sporting Goods           2
# Strength Training        6
# Tennis & Racquet         4
# Toys                     5
# Trade-In                13
# Video Games              1
# Water Sports             3
# Women's Apparel         15
# Women's Clothing         4
# Women's Golf Clubs       6
# Name: product_name, dtype: int64

# %%
df['order_item_profit'] = df['order_item_profit_ratio'] * df['sales']
df['order_item_profit']
# Out:
# 0         40.995900
# 1         95.995200
# 2          8.996400
# 3        -95.984000
# 4         53.997300
#             ...
# 15544    114.729927
# 15545     22.989828
# 15546     18.591039
# 15547    -19.415411
# 15548    153.777580
# Name: order_item_profit, Length: 15519, dtype: float64

# %%
bestproductmargin = df.groupby('product_name')['order_item_profit'].mean().reset_index().sort_values(by='order_item_profit',ascending=False).head(10)
bestproductmargin
# Out:
#                                       product_name  order_item_profit
# 71                             SOLE E25 Elliptical         242.924592
# 18                                     Dell Laptop         223.479931
# 51   Nike Kids' Grade School KD VI Basketball Shoe         111.373800
# 34               GoPro HERO3+ Black Edition Camera          87.333750
# 59    Nike Men's Kobe IX Elite Low Basketball Shoe          74.885723
# 26   Fitbit The One Wireless Activity & Sleep Trac          69.756886
# 95                                  Total Gym 1400          69.520100
# 12   Cleveland Golf Collegiate My Custom Wedge 588          64.695267
# 25                                   First aid kit          61.840654
# 107        adidas Brazuca 2014 Official Match Ball          59.917096

# %%
df['order_item_discount_rate']
# Out:
# 0        0.13
# 1        0.07
# 2        0.06
# 3        0.16
# 4        0.15
#          ...
# 15544    0.09
# 15545    0.13
# 15546    0.09
# 15547    0.16
# 15548    0.01
# Name: order_item_discount_rate, Length: 15519, dtype: float64

# %%
def categorize_discount_rate(df):
    # Define the bins and corresponding labels (based on 2.5% intervals)
    bins = [-float('inf'), 0, 0.025, 0.05, 0.075, 0.10, 0.125, 0.15, 0.175, 0.20, 0.225, 0.25, float('inf')]
    labels = [0, 2.5, 5, 7.5, 10, 12.5, 15, 17.5, 20, 22.5, 25]

    # Create a new column with the categorized discount rate based on 2.5% intervals
    df['discount_category'] = pd.cut(df['order_item_discount_rate'], 
                                     bins=bins, 
                                     labels=labels, 
                                     right=False)  # right=False means the intervals are [)

    return df

# %%
def categorize_discount_rate(df):
    # Define the bins and corresponding labels (based on 2.5% intervals)
    bins = [-float('inf'), 0, 0.025, 0.05, 0.075, 0.10, 0.125, 0.15, 0.175, 0.20, 0.225, 0.25, float('inf')]
    labels = [0, 2.5, 5, 7.5, 10, 12.5, 15, 17.5, 20, 22.5, 25, '25+']

    # Create a new column with the categorized discount rate based on 2.5% intervals
    df['discount_category'] = pd.cut(df['order_item_discount_rate'], 
                                     bins=bins, 
                                     labels=labels, 
                                     right=False)  # right=False means the intervals are [)

    return df

new_df = categorize_discount_rate(df)[['order_item_discount_rate', 'discount_category']]

# %%
df[['order_profit_per_order','product_price']]
# Out:
#        order_profit_per_order  product_price
# 0                   32.083145          99.99
# 1                   91.235870         199.99
# 2                    6.965549          49.98
# 3                  -95.401400          59.99
# 4                   44.569000         199.99
# ...                       ...            ...
# 15544              102.063774         399.98
# 15545               25.072104          49.98
# 15546               12.163874          30.00
# 15547              -17.863270          59.99
# 15548              181.285060          99.99
#
# [15519 rows x 2 columns]

# %%
new_df = df[df['order_profit_per_order'] > 0]
new_df = new_df.groupby('customer_segment')['order_profit_per_order'].mean().reset_index().sort_values(by='order_profit_per_order',ascending=False)

# %%
df['category_name'].unique()
# Out:
# array(['Cardio Equipment', 'Water Sports', 'Indoor/Outdoor Games',
#        'Cleats', 'Electronics', "Men's Footwear", 'Shop By Sport',
#        'Fishing', "Women's Apparel", 'Accessories', 'Camping & Hiking',
#        "Girls' Apparel", 'Crafts', 'CDs ', "Women's Clothing",
#        'Video Games', 'Hunting & Shooting', 'Boxing & MMA',
#        'Tennis & Racquet', 'Cameras ', 'Health and Beauty',
#        "Children's Clothing", 'Strength Training', 'DVDs', 'Garden',
#        'Fitness Accessories', 'Golf Balls', 'Pet Supplies',
#        'Golf Apparel', 'Golf Gloves', 'As Seen on  TV!', 'Toys', 'Hockey',
#        'Trade-In', "Men's Golf Clubs", 'Books ', "Men's Clothing",
#        'Sporting Goods', 'Golf Shoes', 'Baby ', "Women's Golf Clubs",
#        'Baseball & Softball', 'Music', 'Consumer Electronics', 'Lacrosse',
#        'Soccer', 'Computers', 'Basketball', "Kids' Golf Clubs"],
#       dtype=object)

# %%
df.groupby('category_name')

# %%
df['order_date']
# Out:
# 0        2015-08-12 00:00:00+01:00
# 1        2017-02-10 00:00:00+00:00
# 2        2015-01-01 00:00:00+00:00
# 3        2017-05-31 00:00:00+01:00
# 4        2015-03-28 00:00:00+00:00
#                    ...
# 15544    2017-04-03 00:00:00+01:00
# 15545    2017-03-06 00:00:00+00:00
# 15546    2015-06-01 00:00:00+01:00
# 15547    2016-01-31 00:00:00+00:00
# 15548    2017-04-16 00:00:00+01:00
# Name: order_date, Length: 15549, dtype: object

# %%
df['order_date'] = pd.to_datetime(df['order_date'],utc=True)
df['order_date']
# Out:
# 0       2015-08-11 23:00:00+00:00
# 1       2017-02-10 00:00:00+00:00
# 2       2015-01-01 00:00:00+00:00
# 3       2017-05-30 23:00:00+00:00
# 4       2015-03-28 00:00:00+00:00
#                    ...
# 15544   2017-04-02 23:00:00+00:00
# 15545   2017-03-06 00:00:00+00:00
# 15546   2015-05-31 23:00:00+00:00
# 15547   2016-01-31 00:00:00+00:00
# 15548   2017-04-15 23:00:00+00:00
# Name: order_date, Length: 15549, dtype: datetime64[ns, UTC]

# %%
# df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# %%
df = df.dropna(subset=['order_date'])

# %%
df['order_date'].dtype
# Out:
# datetime64[ns, UTC]

# %%
df['order_date'] = df['order_date'].dt.tz_localize(None)  # Remove timezone
df['order_period'] = df['order_date'].dt.to_period('M')

# %%
df['order_period']
# Out:
# 0        2015-08
# 1        2017-02
# 2        2015-01
# 3        2017-05
# 4        2015-03
#           ...
# 15544    2017-04
# 15545    2017-03
# 15546    2015-05
# 15547    2016-01
# 15548    2017-04
# Name: order_period, Length: 15549, dtype: period[M]

# %%
df['order_weekday'] = df['order_date'].dt.day_name()
df['order_weekday']
# Out:
# 0         Tuesday
# 1          Friday
# 2        Thursday
# 3         Tuesday
# 4        Saturday
#            ...
# 15544      Sunday
# 15545      Monday
# 15546      Sunday
# 15547      Sunday
# 15548    Saturday
# Name: order_weekday, Length: 15549, dtype: object

# %%
df[['order_status','shipping_mode']]
# Out:
#           order_status   shipping_mode
# 0             COMPLETE  Standard Class
# 1              PENDING  Standard Class
# 2             COMPLETE    Second Class
# 3           PROCESSING    Second Class
# 4             COMPLETE  Standard Class
# ...                ...             ...
# 15544         COMPLETE  Standard Class
# 15545         COMPLETE  Standard Class
# 15546  PENDING_PAYMENT  Standard Class
# 15547          PENDING  Standard Class
# 15548       PROCESSING    Second Class
#
# [15549 rows x 2 columns]

# %%
df.groupby(['shipping_mode','order_status'])['order_id'].count().reset_index()
# Out:
#      shipping_mode     order_status  order_id
# 0      First Class           CLOSED       273
# 1      First Class         COMPLETE       842
# 2      First Class          ON_HOLD       114
# 3      First Class   PAYMENT_REVIEW         6
# 4      First Class          PENDING       266
# 5      First Class  PENDING_PAYMENT       560
# 6      First Class       PROCESSING       330
# 7         Same Day           CLOSED        87
# 8         Same Day         COMPLETE       240
# 9         Same Day          ON_HOLD        34
# 10        Same Day   PAYMENT_REVIEW         2
# 11        Same Day          PENDING       105
# 12        Same Day  PENDING_PAYMENT       183
# 13        Same Day       PROCESSING       108
# 14    Second Class           CLOSED       353
# 15    Second Class         COMPLETE      1076
# 16    Second Class          ON_HOLD       156
# 17    Second Class   PAYMENT_REVIEW        13
# 18    Second Class          PENDING       392
# 19    Second Class  PENDING_PAYMENT       871
# 20    Second Class       PROCESSING       422
# 21  Standard Class           CLOSED      1050
# 22  Standard Class         COMPLETE      3132
# 23  Standard Class          ON_HOLD       457
# 24  Standard Class   PAYMENT_REVIEW        35
# 25  Standard Class          PENDING      1044
# 26  Standard Class  PENDING_PAYMENT      2212
# 27  Standard Class       PROCESSING      1186

# %%
df.groupby(['order_status','shipping_mode'])['order_id'].count().reset_index()
# Out:
#        order_status   shipping_mode  order_id
# 0            CLOSED     First Class       273
# 1            CLOSED        Same Day        87
# 2            CLOSED    Second Class       353
# 3            CLOSED  Standard Class      1050
# 4          COMPLETE     First Class       842
# 5          COMPLETE        Same Day       240
# 6          COMPLETE    Second Class      1076
# 7          COMPLETE  Standard Class      3132
# 8           ON_HOLD     First Class       114
# 9           ON_HOLD        Same Day        34
# 10          ON_HOLD    Second Class       156
# 11          ON_HOLD  Standard Class       457
# 12   PAYMENT_REVIEW     First Class         6
# 13   PAYMENT_REVIEW        Same Day         2
# 14   PAYMENT_REVIEW    Second Class        13
# 15   PAYMENT_REVIEW  Standard Class        35
# 16          PENDING     First Class       266
# 17          PENDING        Same Day       105
# 18          PENDING    Second Class       392
# 19          PENDING  Standard Class      1044
# 20  PENDING_PAYMENT     First Class       560
# 21  PENDING_PAYMENT        Same Day       183
# 22  PENDING_PAYMENT    Second Class       871
# 23  PENDING_PAYMENT  Standard Class      2212
# 24       PROCESSING     First Class       330
# 25       PROCESSING        Same Day       108
# 26       PROCESSING    Second Class       422
# 27       PROCESSING  Standard Class      1186
